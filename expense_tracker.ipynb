# %%
def main():
    print("print")
    #  getting the user input 
    user_input()
    # writing expense in the file 
    expense()
    # reading and summarization of expenses 
    summarization()

# %%
def user_input():
    print("getting the user input: ")

def expense():
    print("writing the expense: ")

def summarization():
    print("redaing and summarizing: ")

# %%
main()
# Out:
# print
# getting the user input:
# writing the expense:
# redaing and summarizing:
